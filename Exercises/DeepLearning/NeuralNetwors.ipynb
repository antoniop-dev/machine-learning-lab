# %%
#say no to warnings!
import warnings
warnings.filterwarnings("ignore")
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = '3'
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.layers import InputLayer, Dense
from tensorflow.keras import Sequential
from tensorflow.keras.backend import clear_session
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Exploring Sequential Neural Networks
# ## Iris dataset

# %%
data = load_iris()

# %%
def get_iris_net():
    model = Sequential()
    model.add(InputLayer(input_shape=(4,)))
    model.add(Dense(32, activation="relu"))
    model.add(Dense(32, activation="relu"))
    model.add(Dense(3, activation="softmax"))
    return model

# %%
clear_session()
X = data["data"]
y = data["target"]
model = get_iris_net()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.33)
# check if data is evenly split
np.unique(y_train, return_counts=True), np.unique(y_test, return_counts=True)
# Out:
# ((array([0, 1, 2]), array([34, 35, 31])),
#  (array([0, 1, 2]), array([16, 15, 19])))

# %%
model.compile(loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# %%
# save training logs, useful for plots
history = model.fit(X_train, y_train, epochs=50, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.3100 - loss: 1.3052 - val_accuracy: 0.3800 - val_loss: 1.0081
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3100 - loss: 1.0356 - val_accuracy: 0.3800 - val_loss: 0.9406
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3300 - loss: 0.9627 - val_accuracy: 0.6200 - val_loss: 0.8986
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5800 - loss: 0.9009 - val_accuracy: 0.6200 - val_loss: 0.8827
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7100 - loss: 0.8605 - val_accuracy: 0.6400 - val_loss: 0.8348
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7800 - loss: 0.8152 - val_accuracy: 0.6200 - val_loss: 0.8075
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7100 - loss: 0.7773 - val_accuracy: 0.6600 - val_loss: 0.7512
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7600 - loss: 0.7348 - val_accuracy: 0.6800 - val_loss: 0.7090
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8500 - loss: 0.6936 - val_accuracy: 0.9000 - val_loss: 0.6713
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8400 - loss: 0.6617 - val_accuracy: 0.7200 - val_loss: 0.6251
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7800 - loss: 0.6330 - val_accuracy: 0.8600 - val_loss: 0.6022
# Epoch 12/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8600 - loss: 0.6046 - val_accuracy: 0.7200 - val_loss: 0.6019
# Epoch 13/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8400 - loss: 0.5862 - val_accuracy: 0.6200 - val_loss: 0.6266
# Epoch 14/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7300 - loss: 0.5730 - val_accuracy: 0.8600 - val_loss: 0.5533
# Epoch 15/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9200 - loss: 0.5397 - val_accuracy: 0.7800 - val_loss: 0.5503
# Epoch 16/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9000 - loss: 0.5231 - val_accuracy: 0.8200 - val_loss: 0.5045
# Epoch 17/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9000 - loss: 0.5067 - val_accuracy: 0.9400 - val_loss: 0.4901
# Epoch 18/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9100 - loss: 0.4893 - val_accuracy: 0.7800 - val_loss: 0.4722
# Epoch 19/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8300 - loss: 0.4890 - val_accuracy: 0.9200 - val_loss: 0.4636
# Epoch 20/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9100 - loss: 0.4637 - val_accuracy: 0.7000 - val_loss: 0.4553
# Epoch 21/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7800 - loss: 0.4675 - val_accuracy: 0.9000 - val_loss: 0.4435
# Epoch 22/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9100 - loss: 0.4465 - val_accuracy: 0.9600 - val_loss: 0.4364
# Epoch 23/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9200 - loss: 0.4317 - val_accuracy: 0.9600 - val_loss: 0.4301
# Epoch 24/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9500 - loss: 0.4226 - val_accuracy: 0.7800 - val_loss: 0.4176
# Epoch 25/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7900 - loss: 0.4260 - val_accuracy: 0.8200 - val_loss: 0.4073
# Epoch 26/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8500 - loss: 0.4080 - val_accuracy: 0.8600 - val_loss: 0.4282
# Epoch 27/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9400 - loss: 0.3966 - val_accuracy: 0.9600 - val_loss: 0.3980
# Epoch 28/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9300 - loss: 0.3918 - val_accuracy: 0.9200 - val_loss: 0.4026
# Epoch 29/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9200 - loss: 0.3927 - val_accuracy: 0.9600 - val_loss: 0.3803
# Epoch 30/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9000 - loss: 0.3740 - val_accuracy: 0.8600 - val_loss: 0.4034
# Epoch 31/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9200 - loss: 0.3679 - val_accuracy: 0.9600 - val_loss: 0.3685
# Epoch 32/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9100 - loss: 0.3613 - val_accuracy: 0.7800 - val_loss: 0.4195
# Epoch 33/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9200 - loss: 0.3617 - val_accuracy: 0.9600 - val_loss: 0.3580
# Epoch 34/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9300 - loss: 0.3495 - val_accuracy: 0.9600 - val_loss: 0.3616
# Epoch 35/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9600 - loss: 0.3442 - val_accuracy: 0.9200 - val_loss: 0.3480
# Epoch 36/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9200 - loss: 0.3450 - val_accuracy: 0.9600 - val_loss: 0.3520
# Epoch 37/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9600 - loss: 0.3308 - val_accuracy: 0.8600 - val_loss: 0.3658
# Epoch 38/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9500 - loss: 0.3265 - val_accuracy: 0.9000 - val_loss: 0.3348
# Epoch 39/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9300 - loss: 0.3331 - val_accuracy: 0.9400 - val_loss: 0.3413
# Epoch 40/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9800 - loss: 0.3149 - val_accuracy: 0.9000 - val_loss: 0.3452
# Epoch 41/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9800 - loss: 0.3093 - val_accuracy: 0.9000 - val_loss: 0.3386
# Epoch 42/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9700 - loss: 0.3106 - val_accuracy: 0.9200 - val_loss: 0.3329
# Epoch 43/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9600 - loss: 0.3089 - val_accuracy: 0.9600 - val_loss: 0.3111
# Epoch 44/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9500 - loss: 0.2988 - val_accuracy: 0.9600 - val_loss: 0.3067
# Epoch 45/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9400 - loss: 0.2994 - val_accuracy: 0.8200 - val_loss: 0.3506
# Epoch 46/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9500 - loss: 0.2903 - val_accuracy: 0.9600 - val_loss: 0.3012
# Epoch 47/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9100 - loss: 0.2919 - val_accuracy: 0.9200 - val_loss: 0.3001
# Epoch 48/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9200 - loss: 0.2901 - val_accuracy: 0.9600 - val_loss: 0.2925
# Epoch 49/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9500 - loss: 0.2771 - val_accuracy: 0.9800 - val_loss: 0.2938
# Epoch 50/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9700 - loss: 0.2704 - val_accuracy: 0.9400 - val_loss: 0.2957

# %%
model.evaluate(X_train,y_train)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9800 - loss: 0.2657
# [0.2657489478588104, 0.9800000190734863]

# %%
model.evaluate(X_test,y_test)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9400 - loss: 0.2957
# [0.2956719398498535, 0.9399999976158142]

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history["loss"], label="loss")
plt.plot(history.history["accuracy"], label="accuracy")
plt.legend()
plt.title("Train")
plt.subplot(1, 2, 2)
plt.plot(history.history["val_loss"], label="val_loss")
plt.plot(history.history["val_accuracy"], label="val_accuracy")
plt.legend()
plt.title("Test");

# %% [markdown]
# ## MNIST dataset

# %%
(X_train, y_train), (X_test, y_test)  = tf.keras.datasets.mnist.load_data()

# %%
X_train.shape, X_test.shape
# Out:
# ((60000, 28, 28), (10000, 28, 28))

# %%
plt.matshow(X_train[1000], cmap="Blues");

# %%
y_train[1000]
# Out:
# np.uint8(0)

# %%
# flatten the images
X_train_flat = np.reshape(X_train, (60000, 28*28))
X_test_flat = np.reshape(X_test, (10000, 28*28))

# standardize the values
X_train_flat = X_train_flat.astype('float32') / 255
X_test_flat = X_test_flat.astype('float32') / 255

# %%
def get_mnist_net():
    model = Sequential()
    model.add(InputLayer(input_shape=(784,)))
    model.add(Dense(500, activation="relu"))
    model.add(Dense(400, activation="relu"))
    model.add(Dense(10, activation="softmax"))
    model.compile(loss="sparse_categorical_crossentropy", metrics=["accuracy"])
    return model

# %%
clear_session()
model = get_mnist_net()

# %%
history = model.fit(X_train_flat, y_train, epochs=10, verbose=1, batch_size=32, validation_data=(X_test_flat, y_test))
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9870 - loss: 0.0468 - val_accuracy: 0.9790 - val_loss: 0.0953
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9895 - loss: 0.0390 - val_accuracy: 0.9780 - val_loss: 0.0905
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9916 - loss: 0.0304 - val_accuracy: 0.9794 - val_loss: 0.1035
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9937 - loss: 0.0237 - val_accuracy: 0.9822 - val_loss: 0.1007
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9947 - loss: 0.0204 - val_accuracy: 0.9807 - val_loss: 0.1020
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9956 - loss: 0.0159 - val_accuracy: 0.9826 - val_loss: 0.0999
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9965 - loss: 0.0130 - val_accuracy: 0.9817 - val_loss: 0.1195
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9967 - loss: 0.0133 - val_accuracy: 0.9822 - val_loss: 0.1296
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9978 - loss: 0.0085 - val_accuracy: 0.9828 - val_loss: 0.1259
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9979 - loss: 0.0068 - val_accuracy: 0.9838 - val_loss: 0.1338

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history["loss"], label="loss")
plt.plot(history.history["accuracy"], label="accuracy")
plt.legend()
plt.title("Train")
plt.subplot(1, 2, 2)
plt.plot(history.history["val_loss"], label="val_loss")
plt.plot(history.history["val_accuracy"], label="val_accuracy")
plt.legend()
plt.title("Test");
